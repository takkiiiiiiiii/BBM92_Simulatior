# %%
from os import getcwd
from os.path import join, basename
from sys import path 

libs_dir = join("/".join(getcwd().split("/")[:-2]))
path.append(libs_dir)

filename = basename(globals()['__vsc_ipynb_file__']).split(".")[0]

import numpy as np
from libs.qchannel_model import *
import matplotlib.pyplot as plt
from libs.figure_config import *
from libs.default_parameters import *
from libs.simulation_tools import *
from qiskit_aer import AerSimulator
from libs.satellite import *
from new_skr import *

# %%
satellite_1293 = LEOsatellite(
    libs_dir + '/data/STARLINK_1293.txt')
location_aizu = np.loadtxt(
    libs_dir + '/data/ogs_loc.txt')
location_sendai = np.loadtxt(
    libs_dir + '/data/ogs_loc_sendai.txt')
year = 2021
day = 357
hour = 16
minute = 29

t = np.arange(0, 241, 10) 
second = 56 + t 
utc = 9

latitude_bob = location_aizu[:, 0]
longitude_bob = location_aizu[:, 1]
elevation_bob = location_aizu[:, 2]

latitude_alice = location_sendai[:, 0]
longitude_alice = location_sendai[:, 1]
elevation_alice = location_sendai[:, 2]

# Bob用のリスト
# Location: Sendai
slant_path_bob_lst = np.zeros(len(second))
zenith_angle_bob_lst = np.zeros(len(second))

# Alice用のリスト
# Location: Aizuwakamatsu
slant_path_alice_lst = np.zeros(len(second))
zenith_angle_alice_lst = np.zeros(len(second))

for idx in range(len(second)):
    # bobとの幾何学的関係を計算
    slant_path_bob_lst[idx], zenith_angle_bob_lst[idx] = satellite_1293.computeGeometricWithUser(
        year, day, hour, minute, second[idx], utc,
        longitude_bob[0], latitude_bob[0], elevation_bob[0] # bobが単一の場合、[0]でアクセス
    )

    slant_path_alice_lst[idx], zenith_angle_alice_lst[idx] = satellite_1293.computeGeometricWithUser(
        year, day, hour, minute, second[idx], utc,
        longitude_alice[0], latitude_alice[0], elevation_alice[0]
    )

slant_path_bob_lst = slant_path_bob_lst * 1000
slant_path_alice_lst = slant_path_alice_lst * 1000

print(f'zenith_angle_bob_lst: {zenith_angle_bob_lst}')
print(f'zenith_angle_alice_lst: {zenith_angle_alice_lst}')
# Out:
# zenith_angle_bob_lst: [59.12231128 56.36761957 53.29942595 49.86960124 46.02580343 41.71462467
#  36.88795594 31.51443373 25.59889386 19.2177631  12.61487602  6.7674352
#   6.48171328 12.17404931 18.77234156 25.17778075 31.12682233 36.53619297
#  41.39769812 45.74103304 49.61362622 53.06877427 56.15900865 58.93278366
#  61.43314946]
# zenith_angle_alice_lst: [59.82220731 57.20571    54.31536344 51.11731306 47.5796426  43.67872882
#  39.41103877 34.81442487 30.00638313 25.25323752 21.08758441 18.41782064
#  18.22698246 20.60210441 24.62188856 29.33180312 34.15113304 38.78495184
#  43.10028831 47.05110381 50.63677524 53.87901238 56.80904791 59.46070142
#  61.86681358]

# %%
num_channel_coefficients = 5000 #100000
num_qubits_per_channel_coefficient = int(1e6)

tau_zen_lst = np.array([0.81, 0.75, 0.55])
# tau_zen_lst = np.array([0.81])

# %%
print("a =", a, "m")
print("n_s =", n_s)
print("lambda_signal =", lambda_signal)
print("wavelength =", wavelength, "m")
print("h_OGS =", h_OGS, "m")
print("h_s =", h_s, "m")
print("h_atm =", h_atm, "m")
print("theta_rad =", theta_rad, "radians")
print("v_wind =", v_wind, "m/s")
print("mu_x =", mu_x, "m")
print("mu_y =", mu_y, "m")
print("sigma_theta_x =", sigma_theta_x, "radians")
print("sigma_theta_y =", sigma_theta_y, "radians")
print("e_0 =", e_0)
print("p_dark =", p_dark)
print("e_pol =", e_pol)
# Out:
# a = 0.75 m
# n_s = 0.1
# lambda_signal = 0.05
# wavelength = 8.5e-07 m
# h_OGS = 10 m
# h_s = 500000 m
# h_atm = 20000 m
# theta_rad = 5e-06 radians
# v_wind = 21 m/s
# mu_x = 0 m
# mu_y = 0 m
# sigma_theta_x = 8.333333333333334e-07 radians
# sigma_theta_y = 8.333333333333334e-07 radians
# e_0 = 0.5
# p_dark = 1e-05
# e_pol = 0.01

# %%
backend = AerSimulator()

qber_simul =  np.zeros((len(tau_zen_lst), len(zenith_angle_alice_lst)))

# %%
for idx in range(len(tau_zen_lst)):
    tau_zen = tau_zen_lst[idx]
    print(f'tau_zen = {tau_zen}')
    
    for jdx in range(len(zenith_angle_alice_lst)):
        total_sifted_bit_length = 0
        total_err_num = 0
        # 各zenith angleペアに対する累積値を初期化
        print(f'tau_zen = {tau_zen}, zenith_angle_alice = {zenith_angle_alice_lst[jdx]}')
        # アリス（Repeater）のパラメータ
        zenith_angle_alice_deg = zenith_angle_alice_lst[jdx]
        zenith_angle_alice_rad = np.radians(zenith_angle_alice_deg)
        slant_path_alice = slant_path_alice_lst[jdx] # アリスの距離
        sigma_R_squared_alice = rytov_variance(
            wavelength, zenith_angle_alice_rad, h_OGS, h_atm, Cn2_profile)
        w_L_alice = slant_path_alice * theta_rad
        w_Leq_squared_alice = equivalent_beam_width_squared(a, w_L_alice)

        # ボブ（User）のパラメータ
        zenith_angle_bob_deg = zenith_angle_bob_lst[jdx]
        zenith_angle_bob_rad = np.radians(zenith_angle_bob_deg)
        slant_path_bob = slant_path_bob_lst[jdx] # ボブの距離
        sigma_R_squared_bob = rytov_variance(
            wavelength, zenith_angle_bob_rad, h_OGS, h_atm, Cn2_profile)
        w_L_bob = slant_path_bob * theta_rad
        w_Leq_squared_bob = equivalent_beam_width_squared(a, w_L_bob)
        
        
        for kdx in range(int(num_channel_coefficients)):
            # print(f'kdx: {kdx}, tau_zen: {tau_zen}, zenith_angle_alice: {zenith_angle_alice_deg}')
            # --- ステップ1: アリスとボブの瞬時チャネル状態をそれぞれ計算 ---

            # アリス(Repeater)の瞬時透過率
            insta_eta_alice = compute_insta_eta(
                tau_zen, zenith_angle_alice_rad, slant_path_alice,
                mu_x, mu_y, sigma_theta_x, sigma_theta_y,
                a, w_Leq_squared_alice, theta_rad, sigma_R_squared_alice
            )
            
            # ボブ(User)の瞬時透過率
            insta_eta_bob = compute_insta_eta(
                tau_zen, zenith_angle_bob_rad, slant_path_bob,
                mu_x, mu_y, sigma_theta_x, sigma_theta_y,
                a, w_Leq_squared_bob, theta_rad, sigma_R_squared_bob
            )
   
            
            n_values = np.arange(11)

            # 平均光子数 lambda_signal に基づくポアソン分布から確率を求める
            p_values_raw = [photon_number_probability(n, lambda_signal) for n in n_values[:10]]
            # print(f'p_values_raw: {p_values_raw}')
            p_values = p_values_raw[:]
            p_values.append(1.0 - sum(p_values))  # p_10 を補完

            # 数値安定性のためにクリップ＆正規化
            p_values = np.array(p_values)
            p_values = np.clip(p_values, 0, 1)
            p_values = p_values / np.sum(p_values)
            array_size = 10**5
            photon_numbers_array = np.random.choice(n_values, size=array_size, p=p_values)
            count_array = Counter(photon_numbers_array)

            count = [count_array.get(n, 0) for n in n_values]

            # （オプション）検出イベント数の初期化
            n_detect_event = [0] * len(n_values)

            
            num_detected_event = 0
            total_num_detected_event = 0           
            for i in range(len(n_detect_event)):
                if count[i] == 0:
                    continue
            
                yield_val = yield_from_photon_number(i, p_dark, insta_eta_alice, insta_eta_bob)
                for _ in range(count[i]):
                    if np.random.rand() < yield_val:
                        n_detect_event[i] += 1
                
                num_detected_event += n_detect_event[i]
            
            total_num_detected_event += num_detected_event
            # print(f"total_num_detected_event: {total_num_detected_event}")
            if total_num_detected_event == 0:
                # print("Hello World")
                continue
            # print(f"n_detect_event: {n_detect_event}")
            
            for i in range(len(n_detect_event)):
                if n_detect_event[i] > 0:
                    yield_val = yield_from_photon_number(
                        i, 
                        p_dark, 
                        insta_eta_alice, 
                        insta_eta_bob
                    )
                    # print(n_detect_event[i]) 
                    current_bob_qber = pauli_x_application_probability_bob(
                        i,
                        e_0,
                        e_pol,
                        yield_val,
                        insta_eta_alice,
                        insta_eta_bob
                    )
                    current_alice_qber = 0
                    if abs(insta_eta_bob - insta_eta_alice) < 1e-15:
                        if insta_eta_bob == 0: # Both are 0
                            term2 = 0 # (1-(1-0)^(i+1))/(0) -> 0
                        else: # Both are non-zero and equal
                            term2 = (i+1) * (1-insta_eta_alice)**i # L'Hopital's rule limit of (x^k-y^k)/(x-y) as x->y is k*x^(k-1)

                        current_bob_qber = e_0 - ((2*(e_0-e_pol)/((i+1)*yield_val)) * (
                            (1-(1-insta_eta_alice)**(i+1)*(1-insta_eta_bob)**(i+1))/(1-(1-insta_eta_alice)*(1-insta_eta_bob)) - term2
                        ))
                    if total_num_detected_event == 0:
                        print("Hello World")
                        continue
                    if n_detect_event[i] > 5000:
                        continue
                        
                    # print(f"Current Alice QBER: {current_alice_qber}, Current Bob QBER: {current_bob_qber}") 
                    count_sifted, count_error = bbm92simulation(
                            n_detect_event[i],
                            current_alice_qber,
                            current_bob_qber,
                            selected_state_id=3
                    )
                    # part_alice, part_bob, err_num= generate_Siftedkey(
                    #     n_detect_event[i],
                    #     current_alice_qber,
                    #     current_bob_qber,
                    #     backend=backend,
                    # )
                    total_err_num += count_error
                    total_sifted_bit_length += count_sifted
                    # print(f'count_sifted: {count_sifted}, count_error: {count_error}')
        print(f'total_sifted_bit_length: {total_sifted_bit_length}, total_err_num: {total_err_num}')
        # 統計的な平均を計算
        if total_sifted_bit_length > 0:
            avg_qber = total_err_num / total_sifted_bit_length
        else:
            avg_qber = 0.0
        qber_simul[idx][jdx] = avg_qber
        print(f'Average QBER(%): {avg_qber:.8f} (tau_zen: {tau_zen}, zenith_angle_alice: {zenith_angle_alice_deg})')
# Out:
# tau_zen = 0.81
# tau_zen = 0.81, zenith_angle_alice = 59.82220730839252
# total_sifted_bit_length: 20629, total_err_num: 1061
# Average QBER(%): 0.05143245 (tau_zen: 0.81, zenith_angle_alice: 59.82220730839252)
# tau_zen = 0.81, zenith_angle_alice = 57.2057100008884
# total_sifted_bit_length: 26547, total_err_num: 1375
# Average QBER(%): 0.05179493 (tau_zen: 0.81, zenith_angle_alice: 57.2057100008884)
# tau_zen = 0.81, zenith_angle_alice = 54.31536343955395
# total_sifted_bit_length: 35174, total_err_num: 1784
# Average QBER(%): 0.05071928 (tau_zen: 0.81, zenith_angle_alice: 54.31536343955395)
# tau_zen = 0.81, zenith_angle_alice = 51.117313059419615
# total_sifted_bit_length: 48005, total_err_num: 2479
# Average QBER(%): 0.05164045 (tau_zen: 0.81, zenith_angle_alice: 51.117313059419615)
# tau_zen = 0.81, zenith_angle_alice = 47.57964259638222
# total_sifted_bit_length: 65070, total_err_num: 3282
# Average QBER(%): 0.05043799 (tau_zen: 0.81, zenith_angle_alice: 47.57964259638222)
# tau_zen = 0.81, zenith_angle_alice = 43.6787288239362
# total_sifted_bit_length: 85805, total_err_num: 4326
# Average QBER(%): 0.05041664 (tau_zen: 0.81, zenith_angle_alice: 43.6787288239362)
# tau_zen = 0.81, zenith_angle_alice = 39.41103877325696
# total_sifted_bit_length: 109726, total_err_num: 5426
# Average QBER(%): 0.04945045 (tau_zen: 0.81, zenith_angle_alice: 39.41103877325696)
# tau_zen = 0.81, zenith_angle_alice = 34.81442486834874
# total_sifted_bit_length: 138623, total_err_num: 6766
# Average QBER(%): 0.04880864 (tau_zen: 0.81, zenith_angle_alice: 34.81442486834874)
# tau_zen = 0.81, zenith_angle_alice = 30.006383127376125
# total_sifted_bit_length: 174496, total_err_num: 8518
# Average QBER(%): 0.04881487 (tau_zen: 0.81, zenith_angle_alice: 30.006383127376125)
# tau_zen = 0.81, zenith_angle_alice = 25.25323751595485
# total_sifted_bit_length: 202149, total_err_num: 9862
# Average QBER(%): 0.04878580 (tau_zen: 0.81, zenith_angle_alice: 25.25323751595485)
# tau_zen = 0.81, zenith_angle_alice = 21.087584413716755
# total_sifted_bit_length: 231960, total_err_num: 11136
# Average QBER(%): 0.04800828 (tau_zen: 0.81, zenith_angle_alice: 21.087584413716755)
# tau_zen = 0.81, zenith_angle_alice = 18.417820642352908
# total_sifted_bit_length: 244818, total_err_num: 11887
# Average QBER(%): 0.04855444 (tau_zen: 0.81, zenith_angle_alice: 18.417820642352908)
# tau_zen = 0.81, zenith_angle_alice = 18.226982459060977
# total_sifted_bit_length: 241662, total_err_num: 11635
# Average QBER(%): 0.04814576 (tau_zen: 0.81, zenith_angle_alice: 18.226982459060977)
# tau_zen = 0.81, zenith_angle_alice = 20.60210441282841
# total_sifted_bit_length: 236779, total_err_num: 11497
# Average QBER(%): 0.04855583 (tau_zen: 0.81, zenith_angle_alice: 20.60210441282841)
# tau_zen = 0.81, zenith_angle_alice = 24.621888560754243
# total_sifted_bit_length: 207458, total_err_num: 10015
# Average QBER(%): 0.04827483 (tau_zen: 0.81, zenith_angle_alice: 24.621888560754243)
# tau_zen = 0.81, zenith_angle_alice = 29.331803116796927
# total_sifted_bit_length: 175885, total_err_num: 8694
# Average QBER(%): 0.04943003 (tau_zen: 0.81, zenith_angle_alice: 29.331803116796927)
# tau_zen = 0.81, zenith_angle_alice = 34.15113304011096
# total_sifted_bit_length: 144361, total_err_num: 7169
# Average QBER(%): 0.04966023 (tau_zen: 0.81, zenith_angle_alice: 34.15113304011096)
# tau_zen = 0.81, zenith_angle_alice = 38.78495183696875
# total_sifted_bit_length: 113245, total_err_num: 5594
# Average QBER(%): 0.04939732 (tau_zen: 0.81, zenith_angle_alice: 38.78495183696875)
# tau_zen = 0.81, zenith_angle_alice = 43.10028831276119
# total_sifted_bit_length: 86952, total_err_num: 4342
# Average QBER(%): 0.04993560 (tau_zen: 0.81, zenith_angle_alice: 43.10028831276119)
# tau_zen = 0.81, zenith_angle_alice = 47.05110380768914
# total_sifted_bit_length: 65121, total_err_num: 3256
# Average QBER(%): 0.04999923 (tau_zen: 0.81, zenith_angle_alice: 47.05110380768914)
# tau_zen = 0.81, zenith_angle_alice = 50.63677523774974
# total_sifted_bit_length: 51305, total_err_num: 2540
# Average QBER(%): 0.04950785 (tau_zen: 0.81, zenith_angle_alice: 50.63677523774974)
# tau_zen = 0.81, zenith_angle_alice = 53.87901237502872
# total_sifted_bit_length: 37875, total_err_num: 1933
# Average QBER(%): 0.05103630 (tau_zen: 0.81, zenith_angle_alice: 53.87901237502872)
# tau_zen = 0.81, zenith_angle_alice = 56.80904790884399
# total_sifted_bit_length: 28229, total_err_num: 1379
# Average QBER(%): 0.04885047 (tau_zen: 0.81, zenith_angle_alice: 56.80904790884399)
# tau_zen = 0.81, zenith_angle_alice = 59.46070141787879
# total_sifted_bit_length: 21072, total_err_num: 1078
# Average QBER(%): 0.05115793 (tau_zen: 0.81, zenith_angle_alice: 59.46070141787879)
# tau_zen = 0.81, zenith_angle_alice = 61.866813583275615
# total_sifted_bit_length: 16715, total_err_num: 859
# Average QBER(%): 0.05139097 (tau_zen: 0.81, zenith_angle_alice: 61.866813583275615)
# tau_zen = 0.75
# tau_zen = 0.75, zenith_angle_alice = 59.82220730839252
# total_sifted_bit_length: 15050, total_err_num: 735
# Average QBER(%): 0.04883721 (tau_zen: 0.75, zenith_angle_alice: 59.82220730839252)
# tau_zen = 0.75, zenith_angle_alice = 57.2057100008884
# total_sifted_bit_length: 21217, total_err_num: 1049
# Average QBER(%): 0.04944149 (tau_zen: 0.75, zenith_angle_alice: 57.2057100008884)
# tau_zen = 0.75, zenith_angle_alice = 54.31536343955395
# total_sifted_bit_length: 28500, total_err_num: 1477
# Average QBER(%): 0.05182456 (tau_zen: 0.75, zenith_angle_alice: 54.31536343955395)
# tau_zen = 0.75, zenith_angle_alice = 51.117313059419615
# total_sifted_bit_length: 37325, total_err_num: 1943
# Average QBER(%): 0.05205626 (tau_zen: 0.75, zenith_angle_alice: 51.117313059419615)
# tau_zen = 0.75, zenith_angle_alice = 47.57964259638222
# total_sifted_bit_length: 53210, total_err_num: 2771
# Average QBER(%): 0.05207668 (tau_zen: 0.75, zenith_angle_alice: 47.57964259638222)
# tau_zen = 0.75, zenith_angle_alice = 43.6787288239362
# total_sifted_bit_length: 67788, total_err_num: 3484
# Average QBER(%): 0.05139553 (tau_zen: 0.75, zenith_angle_alice: 43.6787288239362)
# tau_zen = 0.75, zenith_angle_alice = 39.41103877325696
# total_sifted_bit_length: 90277, total_err_num: 4484
# Average QBER(%): 0.04966935 (tau_zen: 0.75, zenith_angle_alice: 39.41103877325696)
# tau_zen = 0.75, zenith_angle_alice = 34.81442486834874
# total_sifted_bit_length: 114189, total_err_num: 5641
# Average QBER(%): 0.04940056 (tau_zen: 0.75, zenith_angle_alice: 34.81442486834874)
# tau_zen = 0.75, zenith_angle_alice = 30.006383127376125
# total_sifted_bit_length: 145804, total_err_num: 7191
# Average QBER(%): 0.04931963 (tau_zen: 0.75, zenith_angle_alice: 30.006383127376125)
# tau_zen = 0.75, zenith_angle_alice = 25.25323751595485
# total_sifted_bit_length: 174825, total_err_num: 8496
# Average QBER(%): 0.04859717 (tau_zen: 0.75, zenith_angle_alice: 25.25323751595485)
# tau_zen = 0.75, zenith_angle_alice = 21.087584413716755
# total_sifted_bit_length: 196748, total_err_num: 9616
# Average QBER(%): 0.04887470 (tau_zen: 0.75, zenith_angle_alice: 21.087584413716755)
# tau_zen = 0.75, zenith_angle_alice = 18.417820642352908
# total_sifted_bit_length: 211670, total_err_num: 10419
# Average QBER(%): 0.04922285 (tau_zen: 0.75, zenith_angle_alice: 18.417820642352908)
# tau_zen = 0.75, zenith_angle_alice = 18.226982459060977
# total_sifted_bit_length: 216878, total_err_num: 10377
# Average QBER(%): 0.04784718 (tau_zen: 0.75, zenith_angle_alice: 18.226982459060977)
# tau_zen = 0.75, zenith_angle_alice = 20.60210441282841
# total_sifted_bit_length: 198623, total_err_num: 9891
# Average QBER(%): 0.04979786 (tau_zen: 0.75, zenith_angle_alice: 20.60210441282841)
# tau_zen = 0.75, zenith_angle_alice = 24.621888560754243
# total_sifted_bit_length: 176661, total_err_num: 8624
# Average QBER(%): 0.04881666 (tau_zen: 0.75, zenith_angle_alice: 24.621888560754243)
# tau_zen = 0.75, zenith_angle_alice = 29.331803116796927
# total_sifted_bit_length: 147605, total_err_num: 7236
# Average QBER(%): 0.04902273 (tau_zen: 0.75, zenith_angle_alice: 29.331803116796927)
# tau_zen = 0.75, zenith_angle_alice = 34.15113304011096
# total_sifted_bit_length: 118101, total_err_num: 5778
# Average QBER(%): 0.04892423 (tau_zen: 0.75, zenith_angle_alice: 34.15113304011096)
# tau_zen = 0.75, zenith_angle_alice = 38.78495183696875
# total_sifted_bit_length: 93826, total_err_num: 4777
# Average QBER(%): 0.05091339 (tau_zen: 0.75, zenith_angle_alice: 38.78495183696875)
# tau_zen = 0.75, zenith_angle_alice = 43.10028831276119
# total_sifted_bit_length: 70853, total_err_num: 3637
# Average QBER(%): 0.05133163 (tau_zen: 0.75, zenith_angle_alice: 43.10028831276119)
# tau_zen = 0.75, zenith_angle_alice = 47.05110380768914
# total_sifted_bit_length: 54589, total_err_num: 2760
# Average QBER(%): 0.05055964 (tau_zen: 0.75, zenith_angle_alice: 47.05110380768914)
# tau_zen = 0.75, zenith_angle_alice = 50.63677523774974
# total_sifted_bit_length: 39041, total_err_num: 1980
# Average QBER(%): 0.05071591 (tau_zen: 0.75, zenith_angle_alice: 50.63677523774974)
# tau_zen = 0.75, zenith_angle_alice = 53.87901237502872
# total_sifted_bit_length: 29187, total_err_num: 1528
# Average QBER(%): 0.05235207 (tau_zen: 0.75, zenith_angle_alice: 53.87901237502872)
# tau_zen = 0.75, zenith_angle_alice = 56.80904790884399
# total_sifted_bit_length: 21704, total_err_num: 1071
# Average QBER(%): 0.04934574 (tau_zen: 0.75, zenith_angle_alice: 56.80904790884399)
# tau_zen = 0.75, zenith_angle_alice = 59.46070141787879
# total_sifted_bit_length: 16287, total_err_num: 797
# Average QBER(%): 0.04893473 (tau_zen: 0.75, zenith_angle_alice: 59.46070141787879)
# tau_zen = 0.75, zenith_angle_alice = 61.866813583275615
# total_sifted_bit_length: 11478, total_err_num: 593
# Average QBER(%): 0.05166405 (tau_zen: 0.75, zenith_angle_alice: 61.866813583275615)
# tau_zen = 0.55
# tau_zen = 0.55, zenith_angle_alice = 59.82220730839252
# total_sifted_bit_length: 4333, total_err_num: 217
# Average QBER(%): 0.05008078 (tau_zen: 0.55, zenith_angle_alice: 59.82220730839252)
# tau_zen = 0.55, zenith_angle_alice = 57.2057100008884
# total_sifted_bit_length: 6792, total_err_num: 358
# Average QBER(%): 0.05270907 (tau_zen: 0.55, zenith_angle_alice: 57.2057100008884)
# tau_zen = 0.55, zenith_angle_alice = 54.31536343955395
# total_sifted_bit_length: 9775, total_err_num: 505
# Average QBER(%): 0.05166240 (tau_zen: 0.55, zenith_angle_alice: 54.31536343955395)
# tau_zen = 0.55, zenith_angle_alice = 51.117313059419615
# total_sifted_bit_length: 14037, total_err_num: 757
# Average QBER(%): 0.05392890 (tau_zen: 0.55, zenith_angle_alice: 51.117313059419615)
# tau_zen = 0.55, zenith_angle_alice = 47.57964259638222
# total_sifted_bit_length: 20798, total_err_num: 1029
# Average QBER(%): 0.04947591 (tau_zen: 0.55, zenith_angle_alice: 47.57964259638222)
# tau_zen = 0.55, zenith_angle_alice = 43.6787288239362
# total_sifted_bit_length: 30267, total_err_num: 1571
# Average QBER(%): 0.05190471 (tau_zen: 0.55, zenith_angle_alice: 43.6787288239362)
# tau_zen = 0.55, zenith_angle_alice = 39.41103877325696
# total_sifted_bit_length: 41504, total_err_num: 2088
# Average QBER(%): 0.05030840 (tau_zen: 0.55, zenith_angle_alice: 39.41103877325696)
# tau_zen = 0.55, zenith_angle_alice = 34.81442486834874
# total_sifted_bit_length: 55796, total_err_num: 2864
# Average QBER(%): 0.05132984 (tau_zen: 0.55, zenith_angle_alice: 34.81442486834874)
# tau_zen = 0.55, zenith_angle_alice = 30.006383127376125
# total_sifted_bit_length: 71849, total_err_num: 3665
# Average QBER(%): 0.05100976 (tau_zen: 0.55, zenith_angle_alice: 30.006383127376125)
# tau_zen = 0.55, zenith_angle_alice = 25.25323751595485
# total_sifted_bit_length: 90893, total_err_num: 4546
# Average QBER(%): 0.05001485 (tau_zen: 0.55, zenith_angle_alice: 25.25323751595485)
# tau_zen = 0.55, zenith_angle_alice = 21.087584413716755
# total_sifted_bit_length: 104062, total_err_num: 5295
# Average QBER(%): 0.05088313 (tau_zen: 0.55, zenith_angle_alice: 21.087584413716755)
# tau_zen = 0.55, zenith_angle_alice = 18.417820642352908
# total_sifted_bit_length: 114244, total_err_num: 5703
# Average QBER(%): 0.04991947 (tau_zen: 0.55, zenith_angle_alice: 18.417820642352908)
# tau_zen = 0.55, zenith_angle_alice = 18.226982459060977
# total_sifted_bit_length: 113275, total_err_num: 5692
# Average QBER(%): 0.05024939 (tau_zen: 0.55, zenith_angle_alice: 18.226982459060977)
# tau_zen = 0.55, zenith_angle_alice = 20.60210441282841
# total_sifted_bit_length: 107608, total_err_num: 5450
# Average QBER(%): 0.05064679 (tau_zen: 0.55, zenith_angle_alice: 20.60210441282841)
# tau_zen = 0.55, zenith_angle_alice = 24.621888560754243
# total_sifted_bit_length: 91271, total_err_num: 4682
# Average QBER(%): 0.05129778 (tau_zen: 0.55, zenith_angle_alice: 24.621888560754243)
# tau_zen = 0.55, zenith_angle_alice = 29.331803116796927
# total_sifted_bit_length: 74110, total_err_num: 3629
# Average QBER(%): 0.04896775 (tau_zen: 0.55, zenith_angle_alice: 29.331803116796927)
# tau_zen = 0.55, zenith_angle_alice = 34.15113304011096
# total_sifted_bit_length: 57436, total_err_num: 2899
# Average QBER(%): 0.05047357 (tau_zen: 0.55, zenith_angle_alice: 34.15113304011096)
# tau_zen = 0.55, zenith_angle_alice = 38.78495183696875
# total_sifted_bit_length: 42838, total_err_num: 2203
# Average QBER(%): 0.05142630 (tau_zen: 0.55, zenith_angle_alice: 38.78495183696875)
# tau_zen = 0.55, zenith_angle_alice = 43.10028831276119
# total_sifted_bit_length: 30529, total_err_num: 1580
# Average QBER(%): 0.05175407 (tau_zen: 0.55, zenith_angle_alice: 43.10028831276119)
# tau_zen = 0.55, zenith_angle_alice = 47.05110380768914
# total_sifted_bit_length: 21740, total_err_num: 1179
# Average QBER(%): 0.05423183 (tau_zen: 0.55, zenith_angle_alice: 47.05110380768914)
# tau_zen = 0.55, zenith_angle_alice = 50.63677523774974
# total_sifted_bit_length: 15413, total_err_num: 791
# Average QBER(%): 0.05132031 (tau_zen: 0.55, zenith_angle_alice: 50.63677523774974)
# tau_zen = 0.55, zenith_angle_alice = 53.87901237502872
# total_sifted_bit_length: 10352, total_err_num: 529
# Average QBER(%): 0.05110124 (tau_zen: 0.55, zenith_angle_alice: 53.87901237502872)
# tau_zen = 0.55, zenith_angle_alice = 56.80904790884399
# total_sifted_bit_length: 6872, total_err_num: 366
# Average QBER(%): 0.05325960 (tau_zen: 0.55, zenith_angle_alice: 56.80904790884399)
# tau_zen = 0.55, zenith_angle_alice = 59.46070141787879
# total_sifted_bit_length: 4750, total_err_num: 234
# Average QBER(%): 0.04926316 (tau_zen: 0.55, zenith_angle_alice: 59.46070141787879)
# tau_zen = 0.55, zenith_angle_alice = 61.866813583275615
# total_sifted_bit_length: 3062, total_err_num: 135
# Average QBER(%): 0.04408883 (tau_zen: 0.55, zenith_angle_alice: 61.866813583275615)

# %%
plt.scatter(t, qber_simul[0][:]*100)
plt.scatter(t, qber_simul[1][:]*100)
plt.scatter(t, qber_simul[2][:]*100)
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.

# %%
np.save('results/qber_siml_bbm92_test1_n_s01', qber_simul)

# %%
skr_values =  np.zeros((len(tau_zen_lst), len(zenith_angle_alice_lst)))

# %%
# for idx in range(len(tau_zen_lst)):
#     tau_zen = tau_zen_lst[idx]
#     for jdx in range(len(zenith_angle_alice_lst)):
#         zenith_angle_deg = zenith_angle_lst[jdx]
#         zenith_angle_rad = np.radians(zenith_angle_deg)
        
#         w_L = slant_path_lst[jdx] * theta_rad

#         _, yield_values= compute_avg_qber(
#             sigma_theta_x, sigma_theta_y, slant_path_lst[jdx], mu_x, mu_y,
#             zenith_angle_rad, h_OGS, h_atm, w_L, tau_zen, Cn2_profile,
#             a, e_0, p_dark, e_pol, p_AP, n_s, wavelength
#         )
        

#         Q_1, e_1 = compute_Q_1_e_1_ex(
#             sigma_theta_x, sigma_theta_y, slant_path_lst[jdx], mu_x, mu_y,
#             zenith_angle_rad, h_OGS, h_atm, w_L, tau_zen, Cn2_profile,
#             a, e_0, p_dark, e_pol, p_AP, n_s, wavelength
#         )

#         skr_values[idx][jdx] = compute_SKR(
#             qber_simul[idx][jdx], yield_values, Q_1, e_1
#         )
qber_simul = np.load('results/qber_simul_bbm92_test1_8.npy')
for idx in range(len(tau_zen_lst)):
    tau_zen = tau_zen_lst[idx]
    for jdx in range(len(zenith_angle_alice_lst)):
        
        # --- アリスとボブの平均チャネル性能を計算 ---
        # w_Lをそれぞれ計算
        w_L_alice = slant_path_alice_lst[jdx] * theta_rad
        w_L_bob = slant_path_bob_lst[jdx] * theta_rad

        # アリスの性能
        _, yield_alice = compute_avg_qber(
            sigma_theta_x, sigma_theta_y, slant_path_alice_lst[jdx], mu_x, mu_y,
            np.radians(zenith_angle_alice_lst[jdx]), h_OGS, h_atm, w_L_alice, tau_zen, Cn2_profile,
            a, e_0, p_dark, e_pol, p_AP, n_s, wavelength
        )
        
        # ボブの性能
        _, yield_bob = compute_avg_qber(
            sigma_theta_x, sigma_theta_y, slant_path_bob_lst[jdx], mu_x, mu_y,
            np.radians(zenith_angle_bob_lst[jdx]), h_OGS, h_atm, w_L_bob, tau_zen, Cn2_profile,
            a, e_0, p_dark, e_pol, p_AP, n_s, wavelength
        )
        yield_system = yield_alice * yield_bob
        
        skr_values[idx][jdx] = compute_SKR_final(
            qber_system=qber_simul[idx][jdx], # 計算したシステムQBER
            yield_alice=yield_alice,         # 計算したアリスのYield
            yield_bob=yield_bob,           # 計算したボブのYield
            f_ec=1.0,
            rep_rate=1e9
        )

# %%
plt.plot(t, skr_values[0][:]/10**6)
plt.plot(t, skr_values[1][:]/10**6, ls='--')


plt.xlabel(r"Zenith angle")
plt.ylabel(r"Secret key rate (Mbps)")

plt.xlim(0, 240)

plt.grid()
plt.tight_layout()
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.

# %%
np.save('results/skr_simul_bbm92_test1', skr_values)
